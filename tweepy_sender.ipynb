# %%
import tweepy
from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
import socket
import json

# %%
consumer_key=''
consumer_secret=''
access_token=''
access_secret=''

# %%
class TweetsListener(StreamListener):
  # tweet object listens for the tweets
  def __init__(self, csocket):
    self.client_socket = csocket
  def on_data(self, data):
    try:  
      msg = json.loads( data )
      print("new message")
      # if tweet is longer than 140 characters
      if "extended_tweet" in msg:
        # add at the end of each tweet "t_end" 
        self.client_socket\
            .send(str(msg['extended_tweet']['full_text']+"t_end")\
            .encode('utf-8'))         
        print(msg['extended_tweet']['full_text'])
      else:
        # add at the end of each tweet "t_end" 
        self.client_socket\
            .send(str(msg['text']+"t_end")\
            .encode('utf-8'))
        print(msg['text'])
      return True
    except BaseException as e:
        print("Error on_data: %s" % str(e))
    return True
  def on_error(self, status):
    print(status)
    return True

# %%
def sendData(c_socket, keyword):
  print('start sending data from Twitter to socket')
  # authentication based on the credentials
  auth = OAuthHandler(consumer_key, consumer_secret)
  auth.set_access_token(access_token, access_secret)
  # start sending data from the Streaming API 
  twitter_stream = Stream(auth, TweetsListener(c_socket))
  twitter_stream.filter(track = keyword, languages=["en"])

# %% [markdown]
# Sends data to the specified port

# %%
if __name__ == "__main__":
    # server (local machine) creates listening socket
    s = socket.socket()
    host = "0.0.0.0"    
    port = 9077
    s.bind((host, port))
    print('socket is ready')
    # server (local machine) listens for connections
    s.listen(4)
    print('socket is listening')
    # return the socket and the address on the other side of the connection (client side)
    c_socket, addr = s.accept()
    print("Received request from: " + str(addr))
    # select here the keyword for the tweet data
    sendData(c_socket, keyword = ['investing'])
# Out:
# socket is ready
# socket is listening
# Received request from: ('127.0.0.1', 54689)
# start sending data from Twitter to socket
# new message
# It's exhausting investing in people hoping they might be different. And a waste of time lol
# new message
# @RioJplz @AlgodTrading @zhusu No, he's saying to double your investment, once your profit doubles.
# I'm no math wiz, but in my humble opinion there's no one perfect way to go about this. It always depends on the current situation and the asset you're investing in.
# new message
# @scalperSignals Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @OneYoungWorld: To support our #InvestingInEquality collaboration with Leigh-Anne Pinnock &amp; The Black Fund, we’ve added a bespoke design…
# new message
# $GSKY enters an Uptrend as Momentum Indicator exceeded the 0 level on September 1, 2021. View odds for this and other indicators: https://t.co/53nAUmRoQm #GreenSky #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/Pz2at7OCbF
# new message
# RT @ChauncySmartt: Investing in myself cause I know I’m the greatest 💫 @ Orlando, Florida https://t.co/f61iMbemnS
# new message
# share the post about Dex-Trade exchange on Twitter
# GET FREE LINK LHC ZITI,BR, PHUCK COINS with the Dex-Trade exchange - and you already to start investing in cryptocurrencies with! Hurry up, Amount is limited! https://t.co/NFn0P2UWaY #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# My Crypto Strategy on ICONOMI just outperformed BTC.
# Check it out here:
# https://t.co/1Oo775UlaS
# #crypto #bitcoinmining #bitcointrading #investing https://t.co/Fb5PQyoH7r
# new message
# RT @DMTLAND_: This Firm needs more exposure for what they are doing ! My friend shared this check this out
# new message
# @ElectionWiz Investing today will save you the stress of financial crisis tomorrow.. Live the kind of life you want today by investing and trading Bitcoin option. Trade with a professional trader and start making good profits today.
# @LisaDonalldT thank you for your professionalism.
# new message
# RT @Aleeya__aleey: Physiotherapy was the last hope for students and their parents who cannot afford MBBS/ BDS and for those who were sacrif…
# new message
# RT @labourlewis: .@RishiSunak says his govt is investing £12bn on a 10 point plan to meet the climate emergency - when in fact most of it i…
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/OVSnHyPj0x
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# @Moneypurseadv Happy Birthday Sai garu 🙏💐 Happy Teachers Day to you.. you’re my first only guru in investing thank you a lot #happyteachersday
# new message
# RT @labourlewis: .@RishiSunak says his govt is investing £12bn on a 10 point plan to meet the climate emergency - when in fact most of it i…
# new message
# @scalperSignals Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# @Beeld_Nuus Investing today will save you the stress of financial crisis tomorrow.. Live the kind of life you want today by investing and trading Bitcoin option. Trade with a professional trader and start making good profits today.
# @LisaDonalldT thank you for your professionalism.
# new message
# RT @DMTLAND_: This Firm needs more exposure for what they are doing ! My friend shared this check this out
# new message
# RT @Ykamo13: @bmurphypointman Fighting for ecological causes is the future of all generations. Investing in that and gaining money for doin…
# new message
# RT @ndtv: #CryptoWithNDTV | Interested In Cryptocurrency? Here Is A 10-Point Guide On Investing https://t.co/T0By3Zn9yA https://t.co/eYmHVP…
# new message
# Report 237 | Alison McDowell | The Greater Danger: Global Biosecurity State, Human Capital Investing https://t.co/IMr7tslj9D #LBRY via @OdyseeTeam
# new message
# RT @cryptocom: $Doge Is Trending
# Start investing with as little as USD $1
# Download Now
# new message
# RT @Ykamo13: @emilicrypto @PolyPlayCoin @harmonyprotocol @Uniswap @bsc100x @BinanceChain @BscSupportdesk @PancakeSwap @PancakeSwapBot @elon…
# new message
# RT @rleshner: Don’t be angry or jealous about the bags you don’t have; investing isn’t zero-sum.
#
# An open mind will create a lot more value…
# new message
# RT @Aleeya__aleey: It's the matter of life and death for many of physiotherapy students 🙏
# We've already been facing much criticism.
# No more…
# new message
# RT @facts_tesla: This week is not the first time @elonmusk made bold predictions about future $tsla valuation
#
# In 2015 he predicted market…
# new message
# RT @krishstocks: New #investment Ideas for SIP
#
# #HDFCLIFE
#
# #Tatapower
#
# #Ralaxo
#
# #Symphony
#
# #whirlpoolindia
#
# #Escorts
#
# #IDFCFIRSTBank
#
# #Meg…
# new message
# RT @Aleeya__aleey: After 5 years of hardwork and investing in our degree this is how u degrade us?
# Many r trying to end their lives please…
# new message
# @TAHU3DNFT This is worth investing project.
#
# @freeairdropio
# @freelancer
# @Airdro_P
# new message
# RT @Ykamo13: @WSBChairman @Bamedi_0 @TheDogePoundNFT @belgrano_r @ZssBecker @JRNYcrypto @W00DSeth Fighting for ecological causes is the fut…
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/WFfrd0thxc
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# @cryptogabii @TheGraveyardNFT Investing now.
# new message
# $FSBW's Aroon indicator drops into Downtrend on September 3, 2021. View odds for this and other indicators: https://t.co/wke4B1QKvG #FSBan #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/oPExszoGWk
# new message
# RT @option_square: Hey guys were are coming tomorrow with following:
#
# 1) Two strong weekly reversal stocks.
# 2) Two Breakout RE-TEST stock.…
# new message
# @WealthGathers Investing in opportunities 💯
# new message
# RT @rocketdoge_info: WE ARE LIVE ON https://t.co/zPnRpnYPBk NOW
# ⚡️⚡️ ROCKETDOGE TAKE TO THE MOON ⚡️⚡️
#
# #ROCKETDOGE #Binance
# #DeFi #Crypto #…
# new message
# @Cristiano Friends, do not miss investing in 👌Shiba currency👈👈. Listing in a large webull exchange
# 24-hour volume increase You will soon be surprised like before
# new message
# RT @ChrissieGrech: Lies cost lives, Rishi Sunak.
# new message
# @whenAnand Investing on Jadeja the batsmen
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/6v3IB5AOyh
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# Have you ever thought of crashing a wedding?
#
# That's exactly what this Australian startup allows you to accomplish! LEGALLY!
#
# https://t.co/aWFBCrYpwE
#
# #lintvest #investing #investors #startup #startupindia #funding #business #Indians #India #NewDelhi #kolkata #chennai #mumbai https://t.co/I5pDcYB2ES
# new message
# RT @bibibulbuliya: GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have…
# new message
# Like Subscribe and Share my new channel. —&gt; https://t.co/0za4Bfgnyh
# #cryptocurrency #bitcoin #Ethereum #Safemoon #Cardano #shibainu #VeChain #CryptoNews #investing
# new message
# RT @SteadyCompound: Resources that educate better than a CFA.
#
# 👉Warren Buffett's letters
# 👉Twitter
# 👉Writing online
# 👉Podcasts
# 👉The following…
# new message
# @RinkyBegam Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @APompliano: "Listen, I like Bitcoin right. Bitcoin is math…I like the idea of investing in something that’s reliable, consistent, hones…
# new message
# #Harare transport woes
# @NRZ263
#  ? #investing in #railway/tramline transportation for:
# #Ruwa
# #Mabvuku
# #Dzivarasekwa
# #Kuwadzana
# #Norton #commuters
#  @MhonaFelix @MinistryofTID  @ZimTreasury it’s all possible considering what you have already achieved #justdoit #ZimCan #GameChanger
# new message
# @Netwerk24 Investing today will save you the stress of financial crisis tomorrow.. Live the kind of life you want today by investing and trading Bitcoin option. Trade with a professional trader and start making good profits today.
# @LisaDonalldT thank you for your professionalism.
# new message
# RT @CryptopiaHuss: Like Subscribe and Share my new channel. —&gt; https://t.co/0za4Bfgnyh
# #cryptocurrency #bitcoin #Ethereum #Safemoon #Cardan…
# new message
# RT @AggerCapital: Understanding Alibaba $BABA and the risks posed with Investing in the Chinese e-commerce giant.
#
# 🧵.. https://t.co/rWYCSP…
# new message
# And talking of meetings, conference is back! Here's some more details about the event in Oxford in March. Looks like it's going to be a good one!
# new message
# @BusinessLiveSA Investing today will save you the stress of financial crisis tomorrow.. Live the kind of life you want today by investing and trading Bitcoin option. Trade with a professional trader and start making good profits today.
# @LisaDonalldT thank you for your professionalism.
# new message
# RT @HedgeyeDJ: Investing secrets revealed ... https://t.co/3DkyO5aFuv
# new message
# $AAT in +1.27% Uptrend, growing for three consecutive days on September 1, 2021. View odds for this and other indicators: https://t.co/szDSiM4eUw #AmericanAssetsTrust #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/NwDBAPTyfB
# new message
# @ShillDeer Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# 5th consecutive week drops in longs though oil prices #Weekly_Closing were at similar levels to a week before.
#
# Longs reducing is clear sign that oil followed prevailing sentiments when dropped two weeks ago.
#
# #Weekly_Energy_Recap
# #FAISAL_FAEQ #OPEC #OOTT
#
# https://t.co/Z3PNUKmiZ3
# new message
# RT @StocksCall_: 📊Sector wise allocation for Long term portfolio investing:
#
# 🌐FMCG
# Nestle
# Dabur
#
# 🌐Healthcare
# Divis
# Granules
# Metropolis
#
# 🌐IT…
# new message
# Stop investing in #fossilfuel Just. Stop. Another approach complimenting that of @market_forces #emissions #ClimateCrisis #ClimateActionNow
# new message
# RT @PakBenikasim: 👁 very interesting!!
#
# ⬇️⬇️⬇️
# An Essay on Investing in Small Stocks - MicroCapClub https://t.co/THqIqM1GbY
# new message
# RT @OneYoungWorld: To support our #InvestingInEquality collaboration with Leigh-Anne Pinnock &amp; The Black Fund, we’ve added a bespoke design…
# new message
# RT @lintvest: Have you ever thought of crashing a wedding?
#
# That's exactly what this Australian startup allows you to accomplish! LEGALLY!…
# new message
# RT @ModiShubhit: Pandemic taught us that passive income is much much important for everyone. #investing #economy #CoronavirusPandemic
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/NghyuP2VFu
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# @PeterMcCormack Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/yreHnzxvaz
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# 📈 Click here for the best stock alerts. Link in bio 📲
# #stocks #stockmarket #pennystocks #investing #stockstowatch #AMC #wsb #stockstotrade #wallstreet #wallstreet
# $MDIA
# $FULC
# $SGOC
# $KXIN
# $AMC https://t.co/JjPsokI3z0
# new message
# RT @jainchintan67: weekend stock study done.
#
# Newsletter Rolled out for September series members as well.
#
# Weekend study
#
# https://t.co/WomG…
# new message
# Thank you for pointing this out @labourlewis. It is shocking but then again, by now we should not be surprised at the government’s lies or misjudged priorities. #ProgressiveAlliance essential next GE. #GetTheToriesOut #GTTO @UKLabour @LibDems @TheGreenParty @theSNP @Plaid_Cymru
# new message
# RT @SteadyCompound: Resources that educate better than a CFA.
#
# 👉Warren Buffett's letters
# 👉Twitter
# 👉Writing online
# 👉Podcasts
# 👉The following…
# new message
# @ShillDeer @ShillDragon @ShillLion @ElegantCrypto Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# @ComcastHouston Investing today will save you the stress of financial crisis tomorrow.. Live the kind of life you want today by investing and trading Bitcoin option. Trade with a professional trader and start making good profits today.
# @LisaDonalldT thank you for your professionalism.
# new message
# @eNCA @Abramjee Investing today will save you the stress of financial crisis tomorrow.. Live the kind of life you want today by investing and trading Bitcoin option. Trade with a professional trader and start making good profits today.
# @LisaDonalldT thank you for your professionalism.
# new message
# RT @finkarmaIN: Quote of the day!!
#
# #Trading #StockMarket #TradingTips #Investing #StockTrading https://t.co/55IcDUcWgv
# new message
# RT @rocketdoge_info: WE ARE LIVE ON https://t.co/zPnRpnYPBk NOW
# ⚡️⚡️ ROCKETDOGE TAKE TO THE MOON ⚡️⚡️
#
# #ROCKETDOGE #Binance
# #DeFi #Crypto #…
# new message
# $EBTC's Aroon indicator reaches into Uptrend on August 20, 2021. View odds for this and other indicators: https://t.co/rkTL7eVdl0 #EnterpriseBan #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/6qqisPKIqg
# new message
# RT @AxieFarmUK: If you are interested in investing in our scholarship program please direct message me with the subject header ‘investor’…
# new message
# @BusinessInsider Investing today will save you the stress of financial crisis tomorrow.. Live the kind of life you want today by investing and trading Bitcoin option. Trade with a professional trader and start making good profits today.
# @LisaDonalldT thank you for your professionalism.
# new message
# RT @velumania: 3 kinds.
#
# 1. Keep spending - be poor.
# 2.keep saving - be middle class.
# 3.Keep investing - Be rich
#
# Be it time or money,…
# new message
# RT @Yogeshmahajanji: "Seeing the impact of films on Indian society, Pakistan's ISI started investing money in Indian cinema through Dawood…
# new message
# @SergioRamos @SevillaFC Friends, do not miss investing 🤝👍$Shiba currency.👍
#  Listing in a large web exchange 24-hour volume increase You will soon be surprised like before
# new message
# @Dogemongogo Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @chrisdeerin: this is exactly the kind of thing the Scottish govt should be doing. A smart, modern, low-risk way to change communities f…
# new message
# @ImBitcoinRick @MrGrandpaDoge Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @connectgurmeet: For all young investors.
#
# -A 10k per month SIP in Nifty
#
# -with 10% step up every year
#
# -at 12%- 12.5% XIRR
#
# -In 25 yea…
# new message
# RT @IAmAaronWill: Replace alcohol with water
# Replace Netflix with podcasts
# Replace influencers with creators
# Replace overthinking with act…
# new message
# RT @SmartSyncServ: Happy Teachers' Day!
#
# To all our Gurus in Life &amp; Investing!
#
# A good day to share a few things we have learned from 2 g…
# new message
# RT @ChrissieGrech: Lies cost lives, Rishi Sunak.
# new message
# RT @Hiraya_infinity: Every month, every new friend investing, every new axie bought, is a step closer to the ultimate goal of #PlayToEarn,…
# new message
# RT @sportinvesting_: Earn money on your favorite sports without betting!
# SPORT INVESTING is a crypto platform that allows you to earn on th…
# new message
# RT @OneYoungWorld: To support our #InvestingInEquality collaboration with Leigh-Anne Pinnock &amp; The Black Fund, we’ve added a bespoke design…
# new message
# @Mont_Slice Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# RT @velumania: 3 kinds.
#
# 1. Keep spending - be poor.
# 2.keep saving - be middle class.
# 3.Keep investing - Be rich
#
# Be it time or money,…
# new message
# Whatever I learn I pass on to the members, I believe share markets is the best teacher with supreme importance and gives us profound learning experience each and every day.
#
# Wish everyone a happy teacher's day. Godspeed
#
# #investing #Investment #StockMarket #stocks https://t.co/QMLsXUpXFL
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/6MHtFzSLWj
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# RT @20Thunder20: @CryptoDavidBSC @GetdeepONION in this green moment of the market take advantage of investing in $ONION, a HYBRID currency…
# new message
# RT @JasonEBurack: My Wallstformainst YouTube channel is a good place to learn about investing and the economy. I have been making YouTube v…
# new message
# RT @TD_Investor: Investing when you’re young is important — but so is laying a stable financial foundation.
#
# Before you invest, improve you…
# new message
# RT @StocksCall_: 📊Sector wise allocation for Long term portfolio investing:
#
# 🌐FMCG
# Nestle
# Dabur
#
# 🌐Healthcare
# Divis
# Granules
# Metropolis
#
# 🌐IT…
# new message
# @MrProtobuf @ACHCHHESITARAM @iamjosephyoung Imagine blackrock investing in all the mining companies like they know something.
# new message
# Time is your first friend and journeyman in the craft of #financialflexibility
# new message
# #bitcoin rises back above $50,000 By Reuters https://t.co/2HskUtBcga https://t.co/Siq9nl43Uw
# new message
# RT @BiddulphScott: Ozzy pool is on 🔥🔥🔥 I’m #staking  here and loving it. New to #crypto ? jump in this pool, the $ADA is fine! ROI 5% DYOR,…
# new message
# RT @JrInvestor14: FNO to everyone
# I can’t tell you how to get rich quickly, I can tell you how to get poor quickly, by trying to get rich…
# new message
# @CryptoMilliono @Jetoken1 Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# Trading and investing comes with the risk of losing your money. It's not all happiness and rainbows!
#
# Just look at my Massmart position. Not sure why I'm even still holding it. 🙈 #JSEMSM https://t.co/fs3Zt678Qb
# new message
# @YoungInvestor03 From the PoV of the person investing, you can choose a stock, or choose an ETF wherein someone chooses the stocks and their weights for you! More stocks =&gt; Lower risk.
#
# It makes sense for starters to use ETfs, and once they are comfortable, to move onto stock picking!
# new message
# RT @labourlewis: Look at our ageing public transport infrastructure @RishiSunak!! Time to invest! #ClimateAction https://t.co/2YJr8lM5bD ht…
# new message
# $NTST's Aroon indicator reaches into Uptrend on August 16, 2021. View odds for this and other indicators: https://t.co/3U4m7HSj9Y #Netstreit #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/EoEsc4wQcm
# new message
# RT @officialskyswap: Giving some warm welcoming to the Decentralized platform where the virtual reality market is booming worldwide.
#
# Where…
# new message
# @Avatar2A0 @SafeHavenio @Inheriti_com @jurgenschouppe @a_demeulemees @Tambro86 @davidgarethkerr @SafeHavenCGM @vechainofficial @0xPolygon There will come a day when millions of people are establishing decentralized inheritance plans per year… in this not long away future, steady utilization will reduce market swings and you will request for #FixedStaking programs that have similar #APRs.
#
# Investing is a journey 🗺
# new message
# Lil Yachty &amp; Terrell Owens are investing in PlantFuel®, an emerging sports nutrition brand debuting on the market this month. The scientifically focused plant-based wellness company aims to breakthrough into the nutritional retail space. https://t.co/8PRs7MLFr1
# new message
# ▶ These banks offer higher interest than SBI, ICICI, HDFC Bank on fixed deposits - ET Now: These banks offer higher interest than SBI, ICICI, HDFC Bank on fixed deposits  ET Now https://t.co/9KCbnFLdjR
# new message
# Channel Update and My Weekly Pick Ups | Sports Card Collecting and Investing | https://t.co/UoLGZBNBR8 https://t.co/hAKDi2h7gY
# new message
# @GemsFinderBSC Best upcoming crypto is $Qtum $CRT Token
#
# I built it so I know its a gem!
#
# Free $1,000 via AirDrops right inside the app!
#
# https://t.co/vVNKRb2agq
# new message
# What are the factors you look at when investing in a project?
# new message
# @CryptoGucci @MyCrypto Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# @kiranptr8 I stopped investing around June.. I don't understand why market is rising so high wothout any reason😂.
# new message
# RT @the1onepursuit: Well said! Investing in yourself, investing and creating side income are ALL effective ways to build wealth! https://t.…
# new message
# RT @abslmf: Ready for surprise test? Rearrange the given words to form meaningful financial terms. Comment down below how many of these you…
# new message
# @Jetoken1 @CryptoNextGem Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @OneYoungWorld: To support our #InvestingInEquality collaboration with Leigh-Anne Pinnock &amp; The Black Fund, we’ve added a bespoke design…
# new message
# RT @labourlewis: .@RishiSunak says his govt is investing £12bn on a 10 point plan to meet the climate emergency - when in fact most of it i…
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/klbFKU1V7x
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# We #ETH are the true blood and Sole of z @_AfricanUnion. We were alone fighting for the entire African freedom. We R investing our unhinged support to the unity &amp; prosper of African. This why z west r taking coordinated attack on us. Wake up #Africa. @EthiopiaPrevail @PMEthiopia
# new message
# Even if it goes parabolic, $ALBT Can't get back to under $1 again. When the #LMaaS v2 finally launch and the CEO done with the @ElrondNetwork AMA, expect $2..
#
# #BSC #CoinMarketCap #Crypto #blockchain #100xcoin
# new message
# RT @ecomchasedimond: 6 skills I wish I learned in school:
#
# 1. Sales
# 2. Marketing
# 3. Copywriting
# 4. Psychology
# 5. Investing
# 6. Public Speaki…
# new message
# $VRTS enters an Uptrend because Momentum Indicator exceeded the 0 level on September 1, 2021. View odds for this and other indicators: https://t.co/wCPYT6vMGy #VirtusInvestmentPartners #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/BnsrkeyF5n
# new message
# Republic Founder Kendrick Nguyen: Empowering 1 Million People with Private Investing! https://t.co/6nIq4wWSTp https://t.co/0JVIv1716J
# new message
# Invest in Tomorrow but Live for Today! "Let me tell you a secret…. By focusing on here and now happiness we are in fact investing in a better future at the same time!"
# https://t.co/1rh44r7QeY via @MECFSSelfhelpGu #spoonielife #MECFS #pwme
# new message
# RT @labourlewis: .@RishiSunak says his govt is investing £12bn on a 10 point plan to meet the climate emergency - when in fact most of it i…
# new message
# @KyleSamani Buy some Blitmap while you’re investing in @dhof and the communities he can build.
# new message
# RT @daniel_toloko: Investing outside of America doesn't just have to be China
#
# Plenty of amazing companies in
#
# Sweden🇸🇪
# France🇨🇵
# Japan🇯🇵
# Po…
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/0B11oSaHgW
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# Starpunks is almost here! A project unlike any other!!
# A collection of custom designed artworks inspired by ultimate football heroes! Just a couple of days away!!
#
# RT and follow us to stay updated!
#
# #NFT #NFTsClub #NFTarts #Starpunks #investing  #DOYR #Ethereum #Collectibles
# new message
# @Dimitrios_1963 I am going to be investing more money into VR1 as it has huge upside to the share.
# new message
# @Chican3ry Over here (Sweden) we keep finding out that hiring people local to the “hesitant” suburbs, talking to people in their own language, and making it easy to book in your language increases take-up a ton.
# But apparently truly investing in that is just not happening.
# new message
# RT @allbeenews: Generic Gold Commences Drilling for Gold and VMS on Belvais Project, Quebec https://t.co/QVSahBwFLO #Yukon #Gold #Mining #M…
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co
# Visit the website today to arrange a trial - https://t.co/TMz5f1i7s7 https://t.co/dqR9r6A2YL
# new message
# RT @BrianFeroldi: In investing, high emotional intelligence is more important than a high IQ
# new message
# RT @NFTsClub: Starpunks is almost here! A project unlike any other!!
# A collection of custom designed artworks inspired by ultimate football…
# new message
# RT @BrianFeroldi: The best time to start investing was the day you were born
#
# The second best time has been every day since
# new message
# How do you balance out investing in the stock market with your personal ethics? Or can you not (what a horror 😞)?
#
# HUL is ~17% up over the last couple of months and then there's news like this.
#
# How would you ever know this about a small cap company you choose to invest in 😞 https://t.co/e6bDcFVF6b
# new message
# RT @rocketdoge_info: WE ARE LIVE ON https://t.co/zPnRpnYPBk NOW
# ⚡️⚡️ ROCKETDOGE TAKE TO THE MOON ⚡️⚡️
#
# #ROCKETDOGE #Binance
# #DeFi #Crypto #…
# new message
# @WalletConnect Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @NFTsClub: Starpunks is almost here! A project unlike any other!!
# A collection of custom designed artworks inspired by ultimate football…
# new message
# @send2gl @AlanRedKelly @Redvalerie17 @PaulKha61380019 @aquatrekdive @TraceyH4NCG @Redmanbootle @SFoodbanks @billyliar9 @neilsmithgmb @paulinevauxhall @paulholleran1 I meant in terms of the employer investing.
# new message
# @goodso1992 @RicFlairNatrBoy @CryptoshampooO Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @labourlewis: .@RishiSunak says his govt is investing £12bn on a 10 point plan to meet the climate emergency - when in fact most of it i…
# new message
# $IHC in Uptrend: Stochastic indicator stays in overbought zone for 3 days. View odds for this and other indicators: https://t.co/F2mxO0C3lj #IndependenceHolding #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/p916PQrOaV
# new message
# @ValueStockGeek One of the few things i really understood when i started. Never have paid any attention to any of those. One of the elements to keeping investing simple that works for me.
# new message
# RT @Nonhle_Keswa: I’ve realised investing in your bedroom is much more important than other parts of your place. I’ve spent the entire week…
# new message
# What are the facts for $XRP @GaryGensler &amp; @SECGov ?
#
# $XRP is the token that has been USED on #XRPL  "platform" since day 1.
#
# It's also been trading in the secondary market since day 1.
#
# I've been investing in $XRP for 5 years, never bought a single $XRP token from @Ripple
# new message
# RT @RotaryD1090Conf: What does the future hold? Short of investing in a crystal ball, we're not sure if, or how Covid-19 will impact us in…
# new message
# @Chiliz Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/DZnFTKYYfk
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# 7 Things To Learn From Warren Buffet:
#
# - Never lose money
# - Start investing early
# - Live below your means
# - Make money while you sleep
# - Invest in the quality businesses
# - Focus on the long-term investing
# - Patience is  the  most  dangerous   tool in the world of investing
# new message
# Daily Crypto News. Rich People Buying Bitcoin, Hedge Funds Investing in Crypto, Shiba Inu To $1? https://t.co/bCkO6k3uRr https://t.co/N80v7wX1Dj
# new message
# Even the Rich are also investing into cryptocurrencies https://t.co/u9LpTQ2akf
# new message
# Wonderful project that Worth's investing on
# @ChinweoluS
# @_Charlviclara
# @adkk75
# new message
# RT @CGIARnutrition: Investing USD 15.2 billion more in innovation every year will bring food, climate and water goals into reach, argues pa…
# new message
# RT @LiaSae: @Chican3ry Over here (Sweden) we keep finding out that hiring people local to the “hesitant” suburbs, talking to people in thei…
# new message
# @IvanOnTech I am interested in investing in crypto
# new message
# @binance Re-investing of the amount you earned back into one of the pools. This’s called “Compound” and it gives more profit in two ways:
# 1- Direct increase of the original investment.2- Increase in the profit you earn.
# I just tried to explain a term
# #POSI https://t.co/ZNlhkFYv0M
# new message
# @BabyDogeCoin @binance You guys are idiots for investing in a coin that has no usage whatsoever
# new message
# GET FREE ZITI, BR, BKP, ARMX, MER, BT COINS NOW!
# A few minutes a day with the Dex-Trade exchange - and you already have something to start investing in cryptocurrencies with!
# Hurry up!  https://t.co/uZ35Exi049
# #Dex-Trade #Dex-TradeExchange @dextrade_
# new message
# @socios Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# An actual trader will never have time for YouTube, webinar, course selling. Instead he will be enjoying his weekend in pataya if he is really making money in trading.
#
# #investing #TRADINGTIPS #Traders #Webinar @NSEIndia
# new message
# RT @rajivmehta19: Can you find similarities with #investing ? https://t.co/3tYuRX1OJz
# new message
# @CGTNOfficial when is China investing money in Afghanistan, we are waiting for the Afghans to get debt trapped by the Chinese, the way you trapped SriLanka, Pakistan already sold to China, great policy 👍🏼
# new message
# RT @MotilalOswalAMC: If you think investing in Equities is difficult, try index funds, it simplifies investing and can help you build wealt…
# new message
# @jessicasmw I would the first day. Because people usually ask what you do for a living. Crypto investing is part of one's income.
#
# Do you want to be with a person who's afraid of investing in crypto?
#
# They might try to stop you from investing &amp; this might cause arguments in the relationship.
# new message
# RT @RotaryD1090Conf: What does the future hold? Short of investing in a crystal ball, we're not sure if, or how Covid-19 will impact us in…
# new message
# RT @velumania: 3 kinds.
#
# 1. Keep spending - be poor.
# 2.keep saving - be middle class.
# 3.Keep investing - Be rich
#
# Be it time or money,…
# new message
# @hayfrimpong @badweenba Okay
# So does that mean the data provided over there wasn’t true.
# So which entities on the stock are worth investing in
# new message
# RT @NaijaFlyingDr: Lol. You decide. I studied medicine &amp;  surgery with a special interest in Pre-Hospital care. I founded and ran an intern…
# new message
# $AMTI in Uptrend: RSI indicator exits oversold zone. View odds for this and other indicators: https://t.co/8rr0KvrG3q #AppliedMolecularTransport #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/2stKXFQfMd
# new message
# RT @AWDGroup_UK: Investing in #Business #EventManagement can be incredibly beneficial for both your business and your clients
#
# #CorporateE…
# new message
# @CryptoshampooO Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# RT @LeoDiCaprio: Last week’s @ipcc report was sobering, but we can still change course. By investing in nature-based solutions, we can help…
# new message
# RT @SmartSyncServ: Happy Teachers' Day!
#
# To all our Gurus in Life &amp; Investing!
#
# A good day to share a few things we have learned from 2 g…
# new message
# Big day in the UAE after announcing many mega projects that aim to transforming the economy to become knowledge and technology driven. I believe that investing in UAE at the moment is the best decision any investor could make. That’s my choice to invest in THE future.
# new message
# RT @FrankPeelen: https://t.co/SzAa4M8Dol
#
# My Tesla Investment Thesis 3: The Complete 2021 TSLA Investing Guide
#
# A deep dive into Tesla's ve…
# new message
# RT @velumania: 3 kinds.
#
# 1. Keep spending - be poor.
# 2.keep saving - be middle class.
# 3.Keep investing - Be rich
#
# Be it time or money,…
# new message
# @AtomicWallet Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/a2FQB94bhO
# 🌐 WEBSITE https://t.co/prPPnkph1E
# ☑️ TWITTER
# @ComodoFinance.
# new message
# @cz_binance Friends, do not miss investing  👌💯💥Shiba currency👈. Listing in a large webull exchange
# 👉24-hour volume increase You will soon be surprised like before💢💥💥💯
# new message
# RT @CryptoNav4: @StaySAFUOrg Amazing, this is exactly what the crypto space needs! An easy to use scanner that can give you a quick breakdo…
# new message
# RT @labourlewis: Look at our ageing public transport infrastructure @RishiSunak!! Time to invest! #ClimateAction https://t.co/tIekHP9f51
# new message
# @MattWallace888 @Dogemongo_Daily Here’s a micro MarketCap Project👇👇
#
# Comodo Finance is a very small MCAP project that is worth investing some $$ in 💎
#
# ✅6% Redistribution
# ✅Charity Wallet
# ✅50x potential
#
# ▶️TELEGRAM https://t.co/DOgspBoIp5
# 🌐 WEBSITE https://t.co/710mY2w6wC
# ☑️ TWITTER
# @ComodoFinance.
# new message
# @IcyVeinsNinja Hey everyone! If you're looking for a solid investment, you should try investing on ArbiMoon. They offer the extremely cheap gas fee and near instant transactions.
# new message
# RT @OneYoungWorld: To support our #InvestingInEquality collaboration with Leigh-Anne Pinnock &amp; The Black Fund, we’ve added a bespoke design…
# new message
# $VNDA's in Uptrend: Moving Average Convergence Divergence (MACD) Histogram crosses above signal line. View odds for this and other indicators: https://t.co/e4Gh9Mmf3P #VandaPharmaceuticals #stockmarket #stock #technicalanalysis #money #trading #investing #daytrading #news #today https://t.co/XDpYuWYm9Y
# new message
# Even if your outdoor space is minimal, consider investing in a small raised garden bed and plant a few vegetables. No outdoor space? Fresh herbs still do pretty well inside #ConservationAward
# new message
# Although it’s more volatile than bonds and stocks, it’s possible you can make a reasonable sum if you know how to invest in Bitcoin. $BTC #Crypto  https://t.co/EyeHn3qYOj
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-2f5aa09d7e05> in <module>
#      13     print("Received request from: " + str(addr))
#      14     # select here the keyword for the tweet data
# ---> 15     sendData(c_socket, keyword = ['investing'])
#
# <ipython-input-25-0fa713c947e2> in sendData(c_socket, keyword)
#       6   # start sending data from the Streaming API
#       7   twitter_stream = Stream(auth, TweetsListener(c_socket))
# ----> 8   twitter_stream.filter(track = keyword, languages=["en"])
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/.local/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# /usr/lib/python3.8/http/client.py in read(self, amt)
#     453             # Amount is given, implement using readinto
#     454             b = bytearray(amt)
# --> 455             n = self.readinto(b)
#     456             return memoryview(b)[:n].tobytes()
#     457         else:
#
# /usr/lib/python3.8/http/client.py in readinto(self, b)
#     487
#     488         if self.chunked:
# --> 489             return self._readinto_chunked(b)
#     490
#     491         if self.length is not None:
#
# /usr/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     582         try:
#     583             while True:
# --> 584                 chunk_left = self._get_chunk_left()
#     585                 if chunk_left is None:
#     586                     return total_bytes
#
# /usr/lib/python3.8/http/client.py in _get_chunk_left(self)
#     550                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     551             try:
# --> 552                 chunk_left = self._read_next_chunk_size()
#     553             except ValueError:
#     554                 raise IncompleteRead(b'')
#
# /usr/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     510     def _read_next_chunk_size(self):
#     511         # Read the next chunk size from the file
# --> 512         line = self.fp.readline(_MAXLINE + 1)
#     513         if len(line) > _MAXLINE:
#     514             raise LineTooLong("chunk size")
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
